# %%
from pathlib import Path
import yaml

# Open and read the YAML file
with open(Path('~/Documents/tokens.yaml').expanduser(), 'r') as fp:
    tokens = yaml.safe_load(fp)

# %%
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

# Email credentials
sender_email = "shenyingningsyn@gmail.com"
app_password = tokens['gmail']
receiver_email = "danielleungdaniel@gmail.com"

# Email content
subject = "Test Email from Python"
body = "Hello, this is a test email sent from Python!"

# Create a MIME message
message = MIMEMultipart()
message["From"] = sender_email
message["To"] = receiver_email
message["Subject"] = subject

# Attach the plain text body
message.attach(MIMEText(body, "plain"))

# Send the email
try:
    # Connect to Gmail's SMTP server
    with smtplib.SMTP("smtp.gmail.com", 587) as server:
        server.starttls()  # Secure the connection
        server.login(sender_email, app_password)  # Login
        server.sendmail(sender_email, receiver_email, message.as_string())  # Send email
    print("Email sent successfully!")
except Exception as e:
    print(f"Error sending email: {e}")
# Out:
# Email sent successfully!

# %%
import pickle

import pandas as pd
from runway import *

# %%
with open('example_df_new.bin', 'rb') as fp:
    data_new = pickle.load(fp)

# %%
with open('example_df_old.bin', 'rb') as fp:
    data_old = pickle.load(fp)

# %%
data_old.loc[2, 'is_available'] = 'False'
# Out:
# /tmp/ipykernel_8450/4125110468.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'False' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   data_old.loc[2, 'is_available'] = 'False'

# %%
data_old
# Out:
#                   name    brand  original_price  current_price currency  \
# 0  バックリボンティアードコンビワンピース  dazzlin         14300.0        14300.0      JPY
# 1  バックリボンティアードコンビワンピース  dazzlin         14300.0        14300.0      JPY
# 2  バックリボンティアードコンビワンピース  dazzlin         14300.0        14300.0      JPY
# 3  バックリボンティアードコンビワンピース  dazzlin         14300.0        14300.0      JPY
# 4  バックリボンティアードコンビワンピース  dazzlin         14300.0        14300.0      JPY
# 5  バックリボンティアードコンビワンピース  dazzlin         14300.0        14300.0      JPY
# 6  バックリボンティアードコンビワンピース  dazzlin         14300.0        14300.0      JPY
# 7  バックリボンティアードコンビワンピース  dazzlin         14300.0        14300.0      JPY
# 8  バックリボンティアードコンビワンピース  dazzlin         14300.0        14300.0      JPY
#
#     color size is_available  unit_left     item_id  \
# 0  オフホワイト   XS         True        NaN  0225103023
# 1  オフホワイト    S         True        NaN  0225103023
# 2  オフホワイト    M        False        NaN  0225103023
# 3    ブラック   XS        False        NaN  0225103023
# 4    ブラック    S        False        NaN  0225103023
# 5    ブラック    M        False        NaN  0225103023
# 6    グリーン   XS         True        1.0  0225103023
# 7    グリーン    S         True        NaN  0225103023
# 8    グリーン    M        False        NaN  0225103023
#
#                               asof  \
# 0 2024-12-14 20:02:29.537588+00:00
# 1 2024-12-14 20:02:29.537588+00:00
# 2 2024-12-14 20:02:29.537588+00:00
# 3 2024-12-14 20:02:29.537588+00:00
# 4 2024-12-14 20:02:29.537588+00:00
# 5 2024-12-14 20:02:29.537588+00:00
# 6 2024-12-14 20:02:29.537588+00:00
# 7 2024-12-14 20:02:29.537588+00:00
# 8 2024-12-14 20:02:29.537588+00:00
#
#                                                  url
# 0  https://runway-webstore.com/ap/item/i/m/022510...
# 1  https://runway-webstore.com/ap/item/i/m/022510...
# 2  https://runway-webstore.com/ap/item/i/m/022510...
# 3  https://runway-webstore.com/ap/item/i/m/022510...
# 4  https://runway-webstore.com/ap/item/i/m/022510...
# 5  https://runway-webstore.com/ap/item/i/m/022510...
# 6  https://runway-webstore.com/ap/item/i/m/022510...
# 7  https://runway-webstore.com/ap/item/i/m/022510...
# 8  https://runway-webstore.com/ap/item/i/m/022510...

# %%
data_new
# Out:
#                   name    brand  original_price  current_price currency  \
# 0  バックリボンティアードコンビワンピース  dazzlin         14300.0        14300.0      JPY
# 1  バックリボンティアードコンビワンピース  dazzlin         14300.0        14300.0      JPY
# 2  バックリボンティアードコンビワンピース  dazzlin         14300.0        14300.0      JPY
# 3  バックリボンティアードコンビワンピース  dazzlin         14300.0        14300.0      JPY
# 4  バックリボンティアードコンビワンピース  dazzlin         14300.0        14300.0      JPY
# 5  バックリボンティアードコンビワンピース  dazzlin         14300.0        14300.0      JPY
# 6  バックリボンティアードコンビワンピース  dazzlin         14300.0        14300.0      JPY
# 7  バックリボンティアードコンビワンピース  dazzlin         14300.0        14300.0      JPY
# 8  バックリボンティアードコンビワンピース  dazzlin         14300.0        14300.0      JPY
#
#     color size  is_available  unit_left     item_id  \
# 0  オフホワイト   XS          True        NaN  0225103023
# 1  オフホワイト    S          True        3.0  0225103023
# 2  オフホワイト    M          True        NaN  0225103023
# 3    ブラック   XS          True        NaN  0225103023
# 4    ブラック    S         False        NaN  0225103023
# 5    ブラック    M         False        NaN  0225103023
# 6    グリーン   XS         False        NaN  0225103023
# 7    グリーン    S          True        NaN  0225103023
# 8    グリーン    M         False        NaN  0225103023
#
#                               asof  \
# 0 2024-12-14 20:06:52.785664+00:00
# 1 2024-12-14 20:06:52.785664+00:00
# 2 2024-12-14 20:06:52.785664+00:00
# 3 2024-12-14 20:06:52.785664+00:00
# 4 2024-12-14 20:06:52.785664+00:00
# 5 2024-12-14 20:06:52.785664+00:00
# 6 2024-12-14 20:06:52.785664+00:00
# 7 2024-12-14 20:06:52.785664+00:00
# 8 2024-12-14 20:06:52.785664+00:00
#
#                                                  url
# 0  https://runway-webstore.com/ap/item/i/m/022510...
# 1  https://runway-webstore.com/ap/item/i/m/022510...
# 2  https://runway-webstore.com/ap/item/i/m/022510...
# 3  https://runway-webstore.com/ap/item/i/m/022510...
# 4  https://runway-webstore.com/ap/item/i/m/022510...
# 5  https://runway-webstore.com/ap/item/i/m/022510...
# 6  https://runway-webstore.com/ap/item/i/m/022510...
# 7  https://runway-webstore.com/ap/item/i/m/022510...
# 8  https://runway-webstore.com/ap/item/i/m/022510...

# %%
joined = data_old.merge(data_new, on=['item_id', 'name', 'brand', 'currency', 'color', 'size', 'url'], how='inner')

# %%
joined.loc[(joined['is_available_x'] == False) & (joined['is_available_y'] == True)]
# Out:
#                   name    brand  original_price_x  current_price_x currency  \
# 3  バックリボンティアードコンビワンピース  dazzlin           14300.0          14300.0      JPY
#
#   color size is_available_x  unit_left_x     item_id  \
# 3  ブラック   XS          False          NaN  0225103023
#
#                             asof_x  \
# 3 2024-12-14 20:02:29.537588+00:00
#
#                                                  url  original_price_y  \
# 3  https://runway-webstore.com/ap/item/i/m/022510...           14300.0
#
#    current_price_y  is_available_y  unit_left_y  \
# 3          14300.0            True          NaN
#
#                             asof_y
# 3 2024-12-14 20:06:52.785664+00:00

# %%
alert(data_new, data_old, 'ブラック', 'XS')
# Out:
# Email sent successfully!
