# %%
import logging

import yaml

from scrapers.runway import RunwayScraper

logging.basicConfig(level=logging.INFO)

# %%
with open('./interests/runway.yaml', mode='r') as fp:
    inventory_ids = yaml.safe_load(fp)

# %%
for inventory_id in inventory_ids:
    runway_scraper = RunwayScraper(inventory_id)
    inventory = runway_scraper.scrape()
    display(inventory)
# Out:
# INFO:root:Scraping at 2024-09-28 23:08:00.710082.
# INFO:root:Fetching HTML from https://runway-webstore.com/ap/item/i/m/0224600001.
# INFO:root:Extracting raw inventory from HTML.
# INFO:root:Parsing raw inventory to DataFrame.
#    inventory_id     color size  is_available  amount  \
# 0    0224600001     アイボリー   XS          True     NaN
# 1    0224600001     アイボリー    S          True     NaN
# 2    0224600001     アイボリー    M          True     NaN
# 3    0224600001  チャコールグレー   XS          True     NaN
# 4    0224600001  チャコールグレー    S          True     5.0
# 5    0224600001  チャコールグレー    M          True     NaN
# 6    0224600001      ブラック   XS          True     NaN
# 7    0224600001      ブラック    S          True     NaN
# 8    0224600001      ブラック    M          True     NaN
# 9    0224600001       ピンク   XS          True     NaN
# 10   0224600001       ピンク    S          True     4.0
# 11   0224600001       ピンク    M          True     NaN
# 12   0224600001      パープル   XS         False     NaN
# 13   0224600001      パープル    S         False     NaN
# 14   0224600001      パープル    M         False     NaN
# 15   0224600001        モカ   XS         False     NaN
# 16   0224600001        モカ    S         False     NaN
# 17   0224600001        モカ    M         False     NaN
#
#                     timestamp
# 0  2024-09-28 23:08:00.710082
# 1  2024-09-28 23:08:00.710082
# 2  2024-09-28 23:08:00.710082
# 3  2024-09-28 23:08:00.710082
# 4  2024-09-28 23:08:00.710082
# 5  2024-09-28 23:08:00.710082
# 6  2024-09-28 23:08:00.710082
# 7  2024-09-28 23:08:00.710082
# 8  2024-09-28 23:08:00.710082
# 9  2024-09-28 23:08:00.710082
# 10 2024-09-28 23:08:00.710082
# 11 2024-09-28 23:08:00.710082
# 12 2024-09-28 23:08:00.710082
# 13 2024-09-28 23:08:00.710082
# 14 2024-09-28 23:08:00.710082
# 15 2024-09-28 23:08:00.710082
# 16 2024-09-28 23:08:00.710082
# 17 2024-09-28 23:08:00.710082
# INFO:root:Scraping at 2024-09-28 23:08:04.985703.
# INFO:root:Fetching HTML from https://runway-webstore.com/ap/item/i/m/0224608001.
# INFO:root:Extracting raw inventory from HTML.
# INFO:root:Parsing raw inventory to DataFrame.
# c:\Users\danie\Desktop\shopping-alert\scrapers\runway.py:76: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   inventory['amount'] = inventory['amount'].replace({None: np.nan})
#   inventory_id color size  is_available  amount                  timestamp
# 0   0224608001  ブラック    S          True     NaN 2024-09-28 23:08:04.985703
# 1   0224608001  ブラック    M          True     NaN 2024-09-28 23:08:04.985703
# 2   0224608001   レッド    S          True     NaN 2024-09-28 23:08:04.985703
# 3   0224608001   レッド    M          True     NaN 2024-09-28 23:08:04.985703
# 4   0224608001  ベージュ    S          True     NaN 2024-09-28 23:08:04.985703
# 5   0224608001  ベージュ    M          True     NaN 2024-09-28 23:08:04.985703
# INFO:root:Scraping at 2024-09-28 23:08:07.724359.
# INFO:root:Fetching HTML from https://runway-webstore.com/ap/item/i/m/519850129859551965196516368.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 3
#       1 for inventory_id in inventory_ids:
#       2     runway_scraper = RunwayScraper(inventory_id)
# ----> 3     inventory = runway_scraper.scrape()
#       4     display(inventory)
#
# File c:\Users\danie\Desktop\shopping-alert\scrapers\runway.py:92, in RunwayScraper.scrape(self)
#      90 timestamp = dt.datetime.now()
#      91 logging.info(f'Scraping at {timestamp}.')
# ---> 92 html = self._fetch_html()
#      93 raw_inventory = self._extract_raw_inventory(html)
#      94 inventory = self._parse_to_dataframe(raw_inventory, timestamp)
#
# File c:\Users\danie\Desktop\shopping-alert\scrapers\runway.py:38, in RunwayScraper._fetch_html(self)
#      36 resp = requests.get(self.url)
#      37 if resp.status_code != 200:
# ---> 38     raise RuntimeError(f'Error when fetching from HTML from {self.url}.')
#      39 html = resp.text
#      40 return html
#
# RuntimeError: Error when fetching from HTML from https://runway-webstore.com/ap/item/i/m/519850129859551965196516368.
